# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
product_category=np.array(['Furniture','Technology','Office supplies'])
sales=np.array([4110451.90,4744557.50,3787492.52])

# %%
plt.bar(product_category,sales,color='cyan',edgecolor='orange')
plt.title("Sales across product categories",fontsize=15,color='green',fontweight=5)
plt.xlabel('Product category')
plt.ylabel('Sales')
plt.show()

# %%
#when to use : Visualize the numeric feature (fact) across multiple categories (dimensions)

# %%
plt.bar(product_category,sales,color='cyan',edgecolor='orange')

plt.title("Sales across product categories",fontsize=15,color='green',fontweight=5)
plt.xlabel('Product category')
plt.ylabel('Sales')
plt.show()

# %%
plt.bar(product_category,sales,color='cyan',edgecolor='orange')

plt.title("Sales across product categories",fontsize=15,color='green',fontweight=5)
plt.xlabel('Product category')
plt.ylabel('Sales')

tick_values=np.arange(0,7000000,1000000)
tick_labels=["0L","10L","20L","30L","40L","50L","60L"]

plt.yticks(tick_values,tick_labels)
plt.show()
