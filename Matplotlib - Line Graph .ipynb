# %%
# when to user - To show the trend of a variable over a specified time period

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

# %%
plt.plot(months,sales)

plt.title('Sales across months of 2015')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(sales, 'red', marker = 'o') # Line chart

# %%
plt.plot(sales,'ro') # chatter chart because of only change in the parameters
